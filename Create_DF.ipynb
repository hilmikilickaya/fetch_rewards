# %%
import sys, json
import pandas as pd
import re
from datetime import datetime
import numpy as np

# %%
def create_df_normalize(json_file):
    '''
        Requires : json file
        Return : a structured data frame
    '''
    data = []
    for line in open(f"data/{json_file}", 'r'):
        data.append(json.loads(line))
    df = pd.json_normalize(data, )
    return df

# %%
def rearrange_columns(df, df_name):
    '''
        Requires : a data frame, name of dataframe
        Return : an organized data frame
        
    '''
    # Cleaning the column names
    column_names = list(df.columns)
    for i, name in enumerate(column_names):
        if (len(re.sub("[\w]+." ,"", name))) >= 2:
            column_names[i] = "_".join(name.split(".$")[:2])
        elif "$" in name or len(re.sub("[\w]+." ,"", name)) < 2:
            column_names[i] = name.split(".")[0]
        else:
            column_names[i] = name
    df.columns = column_names
    # Reordering the columns
    
    id_index = column_names.index("_id")
    new_order = column_names[id_index:] + column_names[:id_index]
    df = df[new_order]
    
    # Changing the data types
    for name in df.columns:
        if ("date" in name.lower()) or ("login" in name.lower()):
            df[name] = pd.to_datetime(df[name].astype(int, errors='ignore')/1000, unit='s')
        else:
            df[name]
    df.to_csv(f"{df_name}.csv", index = False)
    return df

# %%
users_df = rearrange_columns(create_df_normalize("users.json"), "users")
brands_df = rearrange_columns(create_df_normalize("brands.json"), "brands")
receipts_df = rearrange_columns(create_df_normalize("receipts.json"), "receipts")

# %%
for i in range(len(receipts_df["rewardsReceiptItemList"])):
    receipts_df["rewardsReceiptItemList"][i] = receipts_df["rewardsReceiptItemList"][i][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-3af03f1c8f9c> in <module>
#       1 for i in range(len(receipts_df["rewardsReceiptItemList"])):
# ----> 2     receipts_df["rewardsReceiptItemList"][i] = receipts_df["rewardsReceiptItemList"][i][0]
#
# KeyError: 0

# %%
temp_df = receipts_df["rewardsReceiptItemList"]

# %%
temp_df = temp_df.apply(pd.Series)

# %%
temp_df = temp_df[['barcode','description','finalPrice','itemPrice','partnerItemId',
 'pointsPayerId','quantityPurchased','rewardsGroup','rewardsProductPartnerId','targetPrice']]

# %%
temp_df
# Out:
#      barcode     description finalPrice itemPrice partnerItemId pointsPayerId  \
# 0       4011  ITEM NOT FOUND      26.00     26.00             1           NaN
# 1       4011  ITEM NOT FOUND          1         1             1           NaN
# 2        NaN             NaN        NaN       NaN             1           NaN
# 3       4011  ITEM NOT FOUND      28.00     28.00             1           NaN
# 4       4011  ITEM NOT FOUND          1         1             1           NaN
# ...      ...             ...        ...       ...           ...           ...
# 1114     NaN             NaN        NaN       NaN           NaN           NaN
# 1115     NaN             NaN        NaN       NaN           NaN           NaN
# 1116     NaN             NaN        NaN       NaN           NaN           NaN
# 1117     NaN             NaN        NaN       NaN           NaN           NaN
# 1118     NaN             NaN        NaN       NaN           NaN           NaN
#
#       quantityPurchased rewardsGroup rewardsProductPartnerId targetPrice
# 0                   5.0          NaN                     NaN         NaN
# 1                   1.0          NaN                     NaN         NaN
# 2                   NaN          NaN                     NaN         NaN
# 3                   4.0          NaN                     NaN         NaN
# 4                   1.0          NaN                     NaN         NaN
# ...                 ...          ...                     ...         ...
# 1114                NaN          NaN                     NaN         NaN
# 1115                NaN          NaN                     NaN         NaN
# 1116                NaN          NaN                     NaN         NaN
# 1117                NaN          NaN                     NaN         NaN
# 1118                NaN          NaN                     NaN         NaN
#
# [1119 rows x 10 columns]

# %%
x = receipts_df.drop(["rewardsReceiptItemList"], axis=1)

# %%
receipts_cleaned_df = pd.concat([x,temp_df], axis=1)

# %%
receipts_cleaned_df.to_csv("data/receipts_updated.csv", index=False)

# %%
df_list = [users_df, brands_df, receipts_cleaned_df]

for df in df_list:
    print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   _id           495 non-null    object
#  1   createdDate   495 non-null    datetime64[ns]
#  2   lastLogin     433 non-null    datetime64[ns]
#  3   active        495 non-null    bool
#  4   role          495 non-null    object
#  5   signUpSource  447 non-null    object
#  6   state         439 non-null    object
# dtypes: bool(1), datetime64[ns](2), object(4)
# memory usage: 23.8+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167 entries, 0 to 1166
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   _id           1167 non-null   object
#  1   cpg_id        1167 non-null   object
#  2   cpg           1167 non-null   object
#  3   brandCode     933 non-null    object
#  4   barcode       1167 non-null   object
#  5   category      1012 non-null   object
#  6   categoryCode  517 non-null    object
#  7   name          1167 non-null   object
#  8   topBrand      555 non-null    object
# dtypes: object(9)
# memory usage: 82.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   _id                      1119 non-null   object
#  1   createDate               1119 non-null   datetime64[ns]
#  2   dateScanned              1119 non-null   datetime64[ns]
#  3   finishedDate             568 non-null    datetime64[ns]
#  4   modifyDate               1119 non-null   datetime64[ns]
#  5   pointsAwardedDate        537 non-null    datetime64[ns]
#  6   purchaseDate             671 non-null    datetime64[ns]
#  7   bonusPointsEarned        544 non-null    float64
#  8   bonusPointsEarnedReason  544 non-null    object
#  9   pointsEarned             609 non-null    object
#  10  purchasedItemCount       635 non-null    float64
#  11  rewardsReceiptStatus     1119 non-null   object
#  12  totalSpent               684 non-null    object
#  13  userId                   1119 non-null   object
#  14  barcode                  64 non-null     object
#  15  description              57 non-null     object
#  16  finalPrice               69 non-null     object
#  17  itemPrice                69 non-null     object
#  18  partnerItemId            71 non-null     object
#  19  pointsPayerId            23 non-null     object
#  20  quantityPurchased        69 non-null     float64
#  21  rewardsGroup             36 non-null     object
#  22  rewardsProductPartnerId  43 non-null     object
#  23  targetPrice              20 non-null     object
# dtypes: datetime64[ns](6), float64(3), object(15)
# memory usage: 209.9+ KB
# None

# %%
for df in df_list:
    display(df.head())
# Out:
#                         _id                   createdDate  \
# 0  5ff1e194b6a9d73a3a9f1052 2021-01-03 15:24:04.799999952
# 1  5ff1e194b6a9d73a3a9f1052 2021-01-03 15:24:04.799999952
# 2  5ff1e194b6a9d73a3a9f1052 2021-01-03 15:24:04.799999952
# 3  5ff1e1eacfcf6c399c274ae6 2021-01-03 15:25:30.553999901
# 4  5ff1e194b6a9d73a3a9f1052 2021-01-03 15:24:04.799999952
#
#                       lastLogin  active      role signUpSource state
# 0 2021-01-03 15:25:37.858000040    True  consumer        Email    WI
# 1 2021-01-03 15:25:37.858000040    True  consumer        Email    WI
# 2 2021-01-03 15:25:37.858000040    True  consumer        Email    WI
# 3 2021-01-03 15:25:30.596999884    True  consumer        Email    WI
# 4 2021-01-03 15:25:37.858000040    True  consumer        Email    WI
#                         _id                    cpg_id   cpg  \
# 0  601ac115be37ce2ead437551  601ac114be37ce2ead437550  Cogs
# 1  601c5460be37ce2ead43755f  5332f5fbe4b03c9a25efd0ba  Cogs
# 2  601ac142be37ce2ead43755d  601ac142be37ce2ead437559  Cogs
# 3  601ac142be37ce2ead43755a  601ac142be37ce2ead437559  Cogs
# 4  601ac142be37ce2ead43755e  5332fa12e4b03c9a25efd1e7  Cogs
#
#                        brandCode       barcode        category  \
# 0                            NaN  511111019862          Baking
# 1                      STARBUCKS  511111519928       Beverages
# 2  TEST BRANDCODE @1612366146176  511111819905          Baking
# 3  TEST BRANDCODE @1612366146051  511111519874          Baking
# 4  TEST BRANDCODE @1612366146827  511111319917  Candy & Sweets
#
#        categoryCode                       name topBrand
# 0            BAKING  test brand @1612366101024    False
# 1         BEVERAGES                  Starbucks    False
# 2            BAKING  test brand @1612366146176    False
# 3            BAKING  test brand @1612366146051    False
# 4  CANDY_AND_SWEETS  test brand @1612366146827    False
#                         _id          createDate         dateScanned  \
# 0  5ff1e1eb0a720f0523000575 2021-01-03 15:25:31 2021-01-03 15:25:31
# 1  5ff1e1bb0a720f052300056b 2021-01-03 15:24:43 2021-01-03 15:24:43
# 2  5ff1e1f10a720f052300057a 2021-01-03 15:25:37 2021-01-03 15:25:37
# 3  5ff1e1ee0a7214ada100056f 2021-01-03 15:25:34 2021-01-03 15:25:34
# 4  5ff1e1d20a7214ada1000561 2021-01-03 15:25:06 2021-01-03 15:25:06
#
#          finishedDate          modifyDate   pointsAwardedDate  \
# 0 2021-01-03 15:25:31 2021-01-03 15:25:36 2021-01-03 15:25:31
# 1 2021-01-03 15:24:43 2021-01-03 15:24:48 2021-01-03 15:24:43
# 2                 NaT 2021-01-03 15:25:42                 NaT
# 3 2021-01-03 15:25:34 2021-01-03 15:25:39 2021-01-03 15:25:34
# 4 2021-01-03 15:25:11 2021-01-03 15:25:11 2021-01-03 15:25:06
#
#          purchaseDate  bonusPointsEarned  \
# 0 2021-01-03 00:00:00              500.0
# 1 2021-01-02 15:24:43              150.0
# 2 2021-01-03 00:00:00                5.0
# 3 2021-01-03 00:00:00                5.0
# 4 2021-01-02 15:25:06                5.0
#
#                              bonusPointsEarnedReason pointsEarned  ...  \
# 0  Receipt number 2 completed, bonus point schedu...        500.0  ...
# 1  Receipt number 5 completed, bonus point schedu...        150.0  ...
# 2                         All-receipts receipt bonus            5  ...
# 3                         All-receipts receipt bonus          5.0  ...
# 4                         All-receipts receipt bonus          5.0  ...
#
#    barcode     description finalPrice itemPrice partnerItemId pointsPayerId  \
# 0     4011  ITEM NOT FOUND      26.00     26.00             1           NaN
# 1     4011  ITEM NOT FOUND          1         1             1           NaN
# 2      NaN             NaN        NaN       NaN             1           NaN
# 3     4011  ITEM NOT FOUND      28.00     28.00             1           NaN
# 4     4011  ITEM NOT FOUND          1         1             1           NaN
#
#   quantityPurchased rewardsGroup rewardsProductPartnerId targetPrice
# 0               5.0          NaN                     NaN         NaN
# 1               1.0          NaN                     NaN         NaN
# 2               NaN          NaN                     NaN         NaN
# 3               4.0          NaN                     NaN         NaN
# 4               1.0          NaN                     NaN         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Data Quality Issues
# - There are duplicated values in users table
# - Missing values in all three tables
# - Wrong data types
